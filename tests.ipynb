# %%
from utils import load_config
from environment import OshaberiEnv
import torch
data_file = "data/kiritan2021-12-07_20-40-44.csv"
conf = load_config("hparams/origin.json")
env = OshaberiEnv(conf,data_file)
init_state = env.reset()
action = torch.rand((3,)) * 2 - 1
ns,r,d,mr = env.step(action)

# %%
import matplotlib.pyplot as plt
plt.imshow(init_state[0])
plt.show()
plt.imshow(init_state[1])
plt.show()
#plt.imshow(ns[0])
#plt.show()
plt.imshow(ns[1])
plt.show()
